# %% [raw]
# ---
# skip_exec: true
# title: Testing cross-reference with holoviews charts
# author: "Luis R. Gonzalez"
# date: 'Aug 20, 2022'
# format:
#     html:
#         code-fold: true
# output-file: cross.html
# description: Testing cross reference with holoviews
# ---

# %%
import pandas as pd
from IPython.display import Markdown
from IPython.core.display import HTML

# %%
df = pd.read_json(
    '{"":{"0":"2000-01-03 00:00:00","1":"2000-01-04 00:00:00","2":"2000-01-05'
    ' 00:00:00","3":"2000-01-06 00:00:00","4":"2000-01-07'
    ' 00:00:00"},"A":{"0":-2.458854,"1":-0.738084,"2":1.718102,"3":0.852164,"4":-0.289673},"B":{"0":0.64294,"1":-0.190354,"2":0.974563,"3":0.185553,"4":0.179118},"C":{"0":1.571082,"1":0.612533,"2":-0.4425,"3":-1.283422,"4":2.149232},"D":{"0":-0.086697,"1":-1.173159,"2":-1.214958,"3":-1.693949,"4":0.588761}}'
)

# %%
# | label: tbl-test-to-markdown-option
# | tbl-cap: Testing with `.to_markdown()`
# | output: true
from IPython.display import Markdown

display(Markdown(df.head().to_markdown()))
# Out:
# |    |                     |         A |         B |         C |         D |
# |---:|:--------------------|----------:|----------:|----------:|----------:|
# |  0 | 2000-01-03 00:00:00 | -2.45885  |  0.64294  |  1.57108  | -0.086697 |
# |  1 | 2000-01-04 00:00:00 | -0.738084 | -0.190354 |  0.612533 | -1.17316  |
# |  2 | 2000-01-05 00:00:00 |  1.7181   |  0.974563 | -0.4425   | -1.21496  |
# |  3 | 2000-01-06 00:00:00 |  0.852164 |  0.185553 | -1.28342  | -1.69395  |
# |  4 | 2000-01-07 00:00:00 | -0.289673 |  0.179118 |  2.14923  |  0.588761 |

# %%
markdown_string = (
    df.head()
    .style.set_table_styles([dict(selector="th", props=[("text-align", "center")])])
    .background_gradient(axis=0)
    .set_table_styles(
        {0: [{"selector": "td:hover", "props": [("font-size", "25px")]}]},
        axis=1,
        overwrite=False,
    )
    .bar(subset=["A", "B"], color="#d65f5f")
)

# %%
# | label: tbl-test_to_markdown_pandas_styler
# | tbl-cap: Embedding a table with panda styler
# | output: true

html = markdown_string.to_html()
HTML(html)
# Out:
# <style type="text/css">
# #T_bb70a th {
#   text-align: center;
# }
# #T_bb70a td:hover.row0 {
#   font-size: 25px;
# }
# #T_bb70a_row0_col1 {
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.9%, transparent 58.9%);
# }
# #T_bb70a_row0_col2 {
#   background-color: #1278b4;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.3%, #d65f5f 16.3%, #d65f5f 71.5%, transparent 71.5%);
# }
# #T_bb70a_row0_col3 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_bb70a_row0_col4 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_bb70a_row1_col1 {
#   background-color: #97b7d7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.2%, #d65f5f 41.2%, #d65f5f 58.9%, transparent 58.9%);
# }
# #T_bb70a_row1_col2 {
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.3%, transparent 16.3%);
# }
# #T_bb70a_row1_col3 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_bb70a_row1_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_bb70a_row2_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, #d65f5f 58.9%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_bb70a_row2_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.3%, #d65f5f 16.3%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_bb70a_row2_col3 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_bb70a_row2_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_bb70a_row3_col1 {
#   background-color: #0569a4;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, #d65f5f 58.9%, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_bb70a_row3_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.3%, #d65f5f 16.3%, #d65f5f 32.3%, transparent 32.3%);
# }
# #T_bb70a_row3_col3, #T_bb70a_row3_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bb70a_row4_col1 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 51.9%, #d65f5f 51.9%, #d65f5f 58.9%, transparent 58.9%);
# }
# #T_bb70a_row4_col2 {
#   background-color: #b9c6e0;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.3%, #d65f5f 16.3%, #d65f5f 31.7%, transparent 31.7%);
# }
# #T_bb70a_row4_col3, #T_bb70a_row4_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bb70a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb70a_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_bb70a_level0_col1" class="col_heading level0 col1" >A</th>
#       <th id="T_bb70a_level0_col2" class="col_heading level0 col2" >B</th>
#       <th id="T_bb70a_level0_col3" class="col_heading level0 col3" >C</th>
#       <th id="T_bb70a_level0_col4" class="col_heading level0 col4" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb70a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb70a_row0_col0" class="data row0 col0" >2000-01-03 00:00:00</td>
#       <td id="T_bb70a_row0_col1" class="data row0 col1" >-2.458854</td>
#       <td id="T_bb70a_row0_col2" class="data row0 col2" >0.642940</td>
#       <td id="T_bb70a_row0_col3" class="data row0 col3" >1.571082</td>
#       <td id="T_bb70a_row0_col4" class="data row0 col4" >-0.086697</td>
#     </tr>
#     <tr>
#       <th id="T_bb70a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb70a_row1_col0" class="data row1 col0" >2000-01-04 00:00:00</td>
#       <td id="T_bb70a_row1_col1" class="data row1 col1" >-0.738084</td>
#       <td id="T_bb70a_row1_col2" class="data row1 col2" >-0.190354</td>
#       <td id="T_bb70a_row1_col3" class="data row1 col3" >0.612533</td>
#       <td id="T_bb70a_row1_col4" class="data row1 col4" >-1.173159</td>
#     </tr>
#     <tr>
#       <th id="T_bb70a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bb70a_row2_col0" class="data row2 col0" >2000-01-05 00:00:00</td>
#       <td id="T_bb70a_row2_col1" class="data row2 col1" >1.718102</td>
#       <td id="T_bb70a_row2_col2" class="data row2 col2" >0.974563</td>
#       <td id="T_bb70a_row2_col3" class="data row2 col3" >-0.442500</td>
#       <td id="T_bb70a_row2_col4" class="data row2 col4" >-1.214958</td>
#     </tr>
#     <tr>
#       <th id="T_bb70a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bb70a_row3_col0" class="data row3 col0" >2000-01-06 00:00:00</td>
#       <td id="T_bb70a_row3_col1" class="data row3 col1" >0.852164</td>
#       <td id="T_bb70a_row3_col2" class="data row3 col2" >0.185553</td>
#       <td id="T_bb70a_row3_col3" class="data row3 col3" >-1.283422</td>
#       <td id="T_bb70a_row3_col4" class="data row3 col4" >-1.693949</td>
#     </tr>
#     <tr>
#       <th id="T_bb70a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bb70a_row4_col0" class="data row4 col0" >2000-01-07 00:00:00</td>
#       <td id="T_bb70a_row4_col1" class="data row4 col1" >-0.289673</td>
#       <td id="T_bb70a_row4_col2" class="data row4 col2" >0.179118</td>
#       <td id="T_bb70a_row4_col3" class="data row4 col3" >2.149232</td>
#       <td id="T_bb70a_row4_col4" class="data row4 col4" >0.588761</td>
#     </tr>
#   </tbody>
# </table>

# %%
# | label: tbl-test-to-markdown-option-quarto-disable
# | tbl-cap: Embedding a table using data-quarto-disable-processing
# | output: true

html = markdown_string.to_html().replace(
    "<table ", '<table data-quarto-disable-processing="true" '
)
HTML(html)
# Out:
# <style type="text/css">
# #T_bb70a th {
#   text-align: center;
# }
# #T_bb70a td:hover.row0 {
#   font-size: 25px;
# }
# #T_bb70a_row0_col1 {
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.9%, transparent 58.9%);
# }
# #T_bb70a_row0_col2 {
#   background-color: #1278b4;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.3%, #d65f5f 16.3%, #d65f5f 71.5%, transparent 71.5%);
# }
# #T_bb70a_row0_col3 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_bb70a_row0_col4 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_bb70a_row1_col1 {
#   background-color: #97b7d7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 41.2%, #d65f5f 41.2%, #d65f5f 58.9%, transparent 58.9%);
# }
# #T_bb70a_row1_col2 {
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.3%, transparent 16.3%);
# }
# #T_bb70a_row1_col3 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_bb70a_row1_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_bb70a_row2_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, #d65f5f 58.9%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_bb70a_row2_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.3%, #d65f5f 16.3%, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_bb70a_row2_col3 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_bb70a_row2_col4 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_bb70a_row3_col1 {
#   background-color: #0569a4;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 58.9%, #d65f5f 58.9%, #d65f5f 79.3%, transparent 79.3%);
# }
# #T_bb70a_row3_col2 {
#   background-color: #b8c6e0;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.3%, #d65f5f 16.3%, #d65f5f 32.3%, transparent 32.3%);
# }
# #T_bb70a_row3_col3, #T_bb70a_row3_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_bb70a_row4_col1 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 51.9%, #d65f5f 51.9%, #d65f5f 58.9%, transparent 58.9%);
# }
# #T_bb70a_row4_col2 {
#   background-color: #b9c6e0;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 16.3%, #d65f5f 16.3%, #d65f5f 31.7%, transparent 31.7%);
# }
# #T_bb70a_row4_col3, #T_bb70a_row4_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table data-quarto-disable-processing="true" id="T_bb70a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb70a_level0_col0" class="col_heading level0 col0" ></th>
#       <th id="T_bb70a_level0_col1" class="col_heading level0 col1" >A</th>
#       <th id="T_bb70a_level0_col2" class="col_heading level0 col2" >B</th>
#       <th id="T_bb70a_level0_col3" class="col_heading level0 col3" >C</th>
#       <th id="T_bb70a_level0_col4" class="col_heading level0 col4" >D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb70a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bb70a_row0_col0" class="data row0 col0" >2000-01-03 00:00:00</td>
#       <td id="T_bb70a_row0_col1" class="data row0 col1" >-2.458854</td>
#       <td id="T_bb70a_row0_col2" class="data row0 col2" >0.642940</td>
#       <td id="T_bb70a_row0_col3" class="data row0 col3" >1.571082</td>
#       <td id="T_bb70a_row0_col4" class="data row0 col4" >-0.086697</td>
#     </tr>
#     <tr>
#       <th id="T_bb70a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bb70a_row1_col0" class="data row1 col0" >2000-01-04 00:00:00</td>
#       <td id="T_bb70a_row1_col1" class="data row1 col1" >-0.738084</td>
#       <td id="T_bb70a_row1_col2" class="data row1 col2" >-0.190354</td>
#       <td id="T_bb70a_row1_col3" class="data row1 col3" >0.612533</td>
#       <td id="T_bb70a_row1_col4" class="data row1 col4" >-1.173159</td>
#     </tr>
#     <tr>
#       <th id="T_bb70a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bb70a_row2_col0" class="data row2 col0" >2000-01-05 00:00:00</td>
#       <td id="T_bb70a_row2_col1" class="data row2 col1" >1.718102</td>
#       <td id="T_bb70a_row2_col2" class="data row2 col2" >0.974563</td>
#       <td id="T_bb70a_row2_col3" class="data row2 col3" >-0.442500</td>
#       <td id="T_bb70a_row2_col4" class="data row2 col4" >-1.214958</td>
#     </tr>
#     <tr>
#       <th id="T_bb70a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bb70a_row3_col0" class="data row3 col0" >2000-01-06 00:00:00</td>
#       <td id="T_bb70a_row3_col1" class="data row3 col1" >0.852164</td>
#       <td id="T_bb70a_row3_col2" class="data row3 col2" >0.185553</td>
#       <td id="T_bb70a_row3_col3" class="data row3 col3" >-1.283422</td>
#       <td id="T_bb70a_row3_col4" class="data row3 col4" >-1.693949</td>
#     </tr>
#     <tr>
#       <th id="T_bb70a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bb70a_row4_col0" class="data row4 col0" >2000-01-07 00:00:00</td>
#       <td id="T_bb70a_row4_col1" class="data row4 col1" >-0.289673</td>
#       <td id="T_bb70a_row4_col2" class="data row4 col2" >0.179118</td>
#       <td id="T_bb70a_row4_col3" class="data row4 col3" >2.149232</td>
#       <td id="T_bb70a_row4_col4" class="data row4 col4" >0.588761</td>
#     </tr>
#   </tbody>
# </table>
